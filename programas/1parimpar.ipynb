# %%
print("************** par o impar ****************")
a= int(input(" Introduce un numero para decirte si es par o impar: "))
if a % 2 == 0:
  print("el numero es par")
else:
    print('El número', a, 'es impar.')

print("fin del programa")
